# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# read files
# file name 
file1 = "1PgQC0tO8XN-wqkNyghWc_-mnrYv_nhSf"                     
file2 = "1IAfLZwu6rJzyWKgBToqwSmmVYU6VbjVs"
# url link download
url1 = f"https://drive.google.com/uc?export=download&id={file1}"
url2 = f"https://drive.google.com/uc?export=download&id={file2}"

df = pd.read_csv(url1) # behavier of market
df1 = pd.read_csv(url2) # trade inferomation

# %%
# info and head of df
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
# info and head of df1
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  float64
# dtypes: bool(1), float64(8), int64(1), object(6)
# memory usage: 24.4+ MB
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 2         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 3         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 4         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp
# 0     True  0.345404  8.950000e+14  1.730000e+12
# 1     True  0.005600  4.430000e+14  1.730000e+12
# 2     True  0.050431  6.600000e+14  1.730000e+12
# 3     True  0.050043  1.080000e+15  1.730000e+12
# 4     True  0.003055  1.050000e+15  1.730000e+12

# %%
# convert column datatype 
df['date'] = pd.to_datetime(df['date'], errors='coerce')
# But to change the print data look, we must apply dt.strftime (convert formatted string)
# Change or reform the date into dd-mm-yyyy
df['date'] = df['date'].dt.strftime('%d-%m-%Y')  # again it convert into object 

# check the changes
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB
#     timestamp  value classification        date
# 0  1517463000     30           Fear  01-02-2018
# 1  1517549400     15   Extreme Fear  02-02-2018
# 2  1517635800     40           Fear  03-02-2018
# 3  1517722200     24   Extreme Fear  04-02-2018
# 4  1517808600     11   Extreme Fear  05-02-2018

# %%
# Convert the data type of timestamp isd
df1['Timestamp IST'] = pd.to_datetime(df1['Timestamp IST'], errors='coerce')
# creat new column and change or reform timestamp into dd-mm-YYYY
df1['date'] = df1['Timestamp IST'].dt.strftime('%d-%m-%Y')

# Check the changes
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     79225 non-null   datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  float64
#  16  date              79225 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(6)
# memory usage: 26.0+ MB
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-02-12 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-02-12 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-02-12 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-02-12 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-02-12 22:50:00     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 2         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 3         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 4         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp        date
# 0     True  0.345404  8.950000e+14  1.730000e+12  12-02-2024
# 1     True  0.005600  4.430000e+14  1.730000e+12  12-02-2024
# 2     True  0.050431  6.600000e+14  1.730000e+12  12-02-2024
# 3     True  0.050043  1.080000e+15  1.730000e+12  12-02-2024
# 4     True  0.003055  1.050000e+15  1.730000e+12  12-02-2024

# %%
# creating new df1 by fillter by df
new_df1 = df1[df1['date'].isin(df['date'])]
# check new df1 
new_df1.info()
new_df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35864 entries, 0 to 209976
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account           35864 non-null  object
#  1   Coin              35864 non-null  object
#  2   Execution Price   35864 non-null  float64
#  3   Size Tokens       35864 non-null  float64
#  4   Size USD          35864 non-null  float64
#  5   Side              35864 non-null  object
#  6   Timestamp IST     35864 non-null  datetime64[ns]
#  7   Start Position    35864 non-null  float64
#  8   Direction         35864 non-null  object
#  9   Closed PnL        35864 non-null  float64
#  10  Transaction Hash  35864 non-null  object
#  11  Order ID          35864 non-null  int64
#  12  Crossed           35864 non-null  bool
#  13  Fee               35864 non-null  float64
#  14  Trade ID          35864 non-null  float64
#  15  Timestamp         35864 non-null  float64
#  16  date              35864 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(6)
# memory usage: 4.7+ MB
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-02-12 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-02-12 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-02-12 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-02-12 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-02-12 22:50:00     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 2         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 3         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 4         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp        date
# 0     True  0.345404  8.950000e+14  1.730000e+12  12-02-2024
# 1     True  0.005600  4.430000e+14  1.730000e+12  12-02-2024
# 2     True  0.050431  6.600000e+14  1.730000e+12  12-02-2024
# 3     True  0.050043  1.080000e+15  1.730000e+12  12-02-2024
# 4     True  0.003055  1.050000e+15  1.730000e+12  12-02-2024

# %%
# remove the null cells if any 
new_df1.dropna(inplace=True)
df.dropna()
# Check the changes
new_df1.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35864 entries, 0 to 209976
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account           35864 non-null  object
#  1   Coin              35864 non-null  object
#  2   Execution Price   35864 non-null  float64
#  3   Size Tokens       35864 non-null  float64
#  4   Size USD          35864 non-null  float64
#  5   Side              35864 non-null  object
#  6   Timestamp IST     35864 non-null  datetime64[ns]
#  7   Start Position    35864 non-null  float64
#  8   Direction         35864 non-null  object
#  9   Closed PnL        35864 non-null  float64
#  10  Transaction Hash  35864 non-null  object
#  11  Order ID          35864 non-null  int64
#  12  Crossed           35864 non-null  bool
#  13  Fee               35864 non-null  float64
#  14  Trade ID          35864 non-null  float64
#  15  Timestamp         35864 non-null  float64
#  16  date              35864 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(6)
# memory usage: 4.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %%
# despation statics of new_df1
new_df1.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  \
# count     35864.000000  3.586400e+04  3.586400e+04
# mean       7596.431745  1.004709e+04  4.920359e+03
# min           0.000005  5.630000e-06  0.000000e+00
# 25%           3.245975  2.588700e+00  1.665300e+02
# 50%          16.390000  2.820000e+01  5.979050e+02
# 75%         172.590000  1.990000e+02  2.220243e+03
# max      103265.000000  1.582244e+07  1.190250e+06
# std       23547.203213  2.060973e+05  2.203314e+04
#
#                        Timestamp IST  Start Position     Closed PnL  \
# count                          35864    3.586400e+04   35864.000000
# mean   2024-11-29 15:03:36.594914560    2.701678e+04     101.070948
# min              2023-01-05 01:06:00   -1.050000e+07 -117990.104100
# 25%              2024-09-12 12:47:00   -2.638983e+02       0.000000
# 50%              2025-01-05 07:06:00    7.010137e+01       0.000000
# 75%              2025-03-04 13:18:00    1.090053e+04      10.735428
# max              2025-05-02 23:59:00    3.050948e+07   71535.716740
# std                              NaN    4.308246e+05    1364.610762
#
#            Order ID           Fee      Trade ID     Timestamp
# count  3.586400e+04  35864.000000  3.586400e+04  3.586400e+04
# mean   5.844251e+10      1.028091  5.619946e+14  1.732824e+12
# min    1.732711e+08     -1.175712  0.000000e+00  1.680000e+12
# 25%    5.240387e+10      0.012518  2.780000e+14  1.730000e+12
# 50%    6.815193e+10      0.084384  5.620000e+14  1.740000e+12
# 75%    7.641909e+10      0.398132  8.460000e+14  1.740000e+12
# max    9.014923e+10    212.298921  1.130000e+15  1.750000e+12
# std    2.240666e+10      4.937482  3.262737e+14  1.082266e+10

# %%
# description statics of df
df.describe()
# Out:
#           timestamp        value
# count  2.644000e+03  2644.000000
# mean   1.631899e+09    46.981089
# std    6.597967e+07    21.827680
# min    1.517463e+09     5.000000
# 25%    1.574811e+09    28.000000
# 50%    1.631900e+09    46.000000
# 75%    1.688989e+09    66.000000
# max    1.746164e+09    95.000000

# %%
# New column netpnl(netprofit)
new_df1['net pnl'] = new_df1['Closed PnL'] - new_df1['Fee']

# %%
# new column of hours and session by day
new_df1['hours'] = new_df1['Timestamp IST'].dt.hour

def day(time):
    if 4<= time <12:
        return 'Morning'
    elif 12<=time<16:
        return 'Afternoon'
    elif 16 <= time < 20:
        return 'Evning'
    else:
        return 'Night'

new_df1['session'] = new_df1['hours'].apply(day)

# %%
# new column by usd per token
new_df1['usd per token'] = new_df1['Size USD']/new_df1['Size Tokens']

# %%
# remove extra spaces
new_df1.columns= new_df1.columns.str.strip()

# %%
# new column position type
new_df1['position type'] = new_df1.apply(lambda x: 'long' if x['Start Position'] > 0  else( 'no position' if x['Start Position']==0 else 'short'), axis=1)  # axis = 1 for only column because it show error without axis.
# basic problem: elif can't be used in a lambda or comprehension because they are single-line expressions

# %%
#  Check the changes
new_df1 .info()
new_df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35864 entries, 0 to 209976
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account           35864 non-null  object
#  1   Coin              35864 non-null  object
#  2   Execution Price   35864 non-null  float64
#  3   Size Tokens       35864 non-null  float64
#  4   Size USD          35864 non-null  float64
#  5   Side              35864 non-null  object
#  6   Timestamp IST     35864 non-null  datetime64[ns]
#  7   Start Position    35864 non-null  float64
#  8   Direction         35864 non-null  object
#  9   Closed PnL        35864 non-null  float64
#  10  Transaction Hash  35864 non-null  object
#  11  Order ID          35864 non-null  int64
#  12  Crossed           35864 non-null  bool
#  13  Fee               35864 non-null  float64
#  14  Trade ID          35864 non-null  float64
#  15  Timestamp         35864 non-null  float64
#  16  date              35864 non-null  object
#  17  net pnl           35864 non-null  float64
#  18  time              35864 non-null  object
#  19  hours             35864 non-null  int32
#  20  session           35864 non-null  object
#  21  usd per token     35864 non-null  float64
#  22  position type     35864 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(10), int32(1), int64(1), object(9)
# memory usage: 6.2+ MB
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-02-12 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-02-12 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-02-12 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-02-12 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-02-12 22:50:00     1289.488521       Buy
#
#    Closed PnL  ...       Fee      Trade ID     Timestamp        date  \
# 0         0.0  ...  0.345404  8.950000e+14  1.730000e+12  12-02-2024
# 1         0.0  ...  0.005600  4.430000e+14  1.730000e+12  12-02-2024
# 2         0.0  ...  0.050431  6.600000e+14  1.730000e+12  12-02-2024
# 3         0.0  ...  0.050043  1.080000e+15  1.730000e+12  12-02-2024
# 4         0.0  ...  0.003055  1.050000e+15  1.730000e+12  12-02-2024
#
#     net pnl      time hours  session usd per token  position type
# 0 -0.345404  22:50:00    22    Night      7.976897    no position
# 1 -0.005600  22:50:00    22    Night      7.980000           long
# 2 -0.050431  22:50:00    22    Night      7.985495           long
# 3 -0.050043  22:50:00    22    Night      7.987411           long
# 4 -0.003055  22:50:00    22    Night      7.989691           long
#
# [5 rows x 23 columns]

# %%
# merging two datasets  
bitcoin = new_df1.merge(df, on='date', how='left')  # merging in this way because they are of diff sizes and to get columns of df into new_df1 and the merger name is bitcoin.

# check changes
bitcoin.info()
bitcoin.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35864 entries, 0 to 35863
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account           35864 non-null  object
#  1   Coin              35864 non-null  object
#  2   Execution Price   35864 non-null  float64
#  3   Size Tokens       35864 non-null  float64
#  4   Size USD          35864 non-null  float64
#  5   Side              35864 non-null  object
#  6   Timestamp IST     35864 non-null  datetime64[ns]
#  7   Start Position    35864 non-null  float64
#  8   Direction         35864 non-null  object
#  9   Closed PnL        35864 non-null  float64
#  10  Transaction Hash  35864 non-null  object
#  11  Order ID          35864 non-null  int64
#  12  Crossed           35864 non-null  bool
#  13  Fee               35864 non-null  float64
#  14  Trade ID          35864 non-null  float64
#  15  Timestamp         35864 non-null  float64
#  16  date              35864 non-null  object
#  17  net pnl           35864 non-null  float64
#  18  time              35864 non-null  object
#  19  hours             35864 non-null  int32
#  20  session           35864 non-null  object
#  21  usd per token     35864 non-null  float64
#  22  position type     35864 non-null  object
#  23  timestamp         35864 non-null  int64
#  24  value             35864 non-null  int64
#  25  classification    35864 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(10), int32(1), int64(3), object(10)
# memory usage: 6.7+ MB
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-02-12 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-02-12 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-02-12 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-02-12 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-02-12 22:50:00     1289.488521       Buy
#
#    Closed PnL  ...        date   net pnl      time  hours  session  \
# 0         0.0  ...  12-02-2024 -0.345404  22:50:00     22    Night
# 1         0.0  ...  12-02-2024 -0.005600  22:50:00     22    Night
# 2         0.0  ...  12-02-2024 -0.050431  22:50:00     22    Night
# 3         0.0  ...  12-02-2024 -0.050043  22:50:00     22    Night
# 4         0.0  ...  12-02-2024 -0.003055  22:50:00     22    Night
#
#    usd per token position type   timestamp value  classification
# 0       7.976897   no position  1707715800    70           Greed
# 1       7.980000          long  1707715800    70           Greed
# 2       7.985495          long  1707715800    70           Greed
# 3       7.987411          long  1707715800    70           Greed
# 4       7.989691          long  1707715800    70           Greed
#
# [5 rows x 26 columns]

# %%
bitcoin.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp', 'date', 'net pnl', 'time', 'hours', 'session',
#        'usd per token', 'position type', 'timestamp', 'value',
#        'classification'],
#       dtype='object')

# %%
for col in bitcoin.select_dtypes(include=np.number):
    plt.figure(figsize=(12, 5))
    sns.violinplot(data=bitcoin, x='classification', y=col )
    plt.title(f'graph of {col} vs classification')
    plt.show()

# %% [markdown]
# # numerical to categorical bivariant
# - exclusive price fear is on top, and greed and extreme greed are on 2nd and 3rd
# - size token greed on top extrem greed on 2nd
# - usd token fear are on top, and greed is on 2nd, and extreme greed is on 3rd
# - starting position, greed most position, and fear and neutral are on the 2nd
# - closed pnl fear make more profit top and extreme greed on 2nd, negative profit greed
# - order id top greed and 2nd fear, and extreme fear
# - fee top is fear and 2nd is greed and lowest is neutral
# - usd per token greed on top and fear on 2nd
# - value most extreme greed and lowest extreme fear
# - The 0xbee account has more orders
# - All are 0 peaks except values 30 and 70 are peak traders buy

# %%
# Stacked bar graphs for category to category
cols = [ 'Coin', 'Side',  'Direction',   'Crossed', 'session','position type']
for col in cols:
    plt.figure(figsize=(12, 7))
    cross_tab = pd.crosstab(bitcoin[col], bitcoin['classification'])
    cross_tab.plot(kind='bar', stacked=True)
    plt.title(f'graphs of {col} per classification')
    plt.show()

# %% [markdown]
# # Categorical to categorical bivariant
# - sides buy(fear>greed) and sell (greed>fear)
# - Most used coins are HYPE, @107, ETH, BTC, and SOL
# - direction fear(closed shot, open long and open short), greed(open long and buy) and extrem greed(sell)
# - cross fear larger
# - session morning and night, fear is the same, but greed is increasing
# - long fear > greed

# %%
# Convert category into numerical
[ 'Coin', 'Side',  'Direction',   'Crossed', 'session','position type']
df = bitcoin.copy()
# comprehenction on dicitionary for get str(key): int(value).
dis1 = {value:index for index, value in enumerate(df['Coin'])}
df['Coin'] = df['Coin'].map(dis1)
dis2 = {'BUY':0, 'SELL':1}
df['Side'] = df['Side'].map(dis2)
dis3 = {'Buy':0, 'Sell':1, 'Open Long':2, 'Close Long':3, 'Spot Dust Conversion':4, 'Open Short':5,'Close Short':6, 'Long > Short':7, 'Short > Long':8}
df['Direction'] = df['Direction'].map(dis3)
dis4 = {True:0, False:1}
df['Crossed'] = df['Crossed'].map(dis4)
dis5 = {'Night':0, 'Afternoon':1, 'Evning':2, 'Morning':3}
df['session'] = df['session'].map(dis5)
dis6 = {'no position':0, 'long':1, 'short':2}
df['position type'] = df['position type'].map(dis6)
dis7 = {'Greed':0, 'Extreme Greed':1, 'Fear':2, 'Extreme Fear':3, 'Neutral':4}
df['classification'] = df['classification'].map(dis7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35864 entries, 0 to 35863
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Account           35864 non-null  object
#  1   Coin              35864 non-null  int64
#  2   Execution Price   35864 non-null  float64
#  3   Size Tokens       35864 non-null  float64
#  4   Size USD          35864 non-null  float64
#  5   Side              35864 non-null  int64
#  6   Timestamp IST     35864 non-null  datetime64[ns]
#  7   Start Position    35864 non-null  float64
#  8   Direction         35864 non-null  int64
#  9   Closed PnL        35864 non-null  float64
#  10  Transaction Hash  35864 non-null  object
#  11  Order ID          35864 non-null  int64
#  12  Crossed           35864 non-null  int64
#  13  Fee               35864 non-null  float64
#  14  Trade ID          35864 non-null  float64
#  15  Timestamp         35864 non-null  float64
#  16  date              35864 non-null  object
#  17  net pnl           35864 non-null  float64
#  18  time              35864 non-null  object
#  19  hours             35864 non-null  int32
#  20  session           35864 non-null  int64
#  21  usd per token     35864 non-null  float64
#  22  position type     35864 non-null  int64
#  23  timestamp         35864 non-null  int64
#  24  value             35864 non-null  int64
#  25  classification    35864 non-null  int64
# dtypes: datetime64[ns](1), float64(10), int32(1), int64(10), object(4)
# memory usage: 7.0+ MB

# %%
# correlation matrix with heatmap
corr_matrix = df.select_dtypes(include=np.number).corr()
# heatmap for correlation matrix
plt.figure(figsize=(12, 5))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# # Multivariant
# - (closed pnl and net pnl) , (usd per token and Execution price) and (order id and timestamp) all of them have extremely strong proportional
# - (position type and direction), (timestamp and orderid) and (fee and usd size)  strong proportional
# - (timestamp and classification ), (timestamp and coin), (order id and coin), (starting position and size token), normal or week proportional
# - (classification and value) and (Timestamp and value) are inversely proportional

# %%
# top 10 coins
df = bitcoin.groupby('Coin').size().reset_index(name='count')
top10 = df.nlargest(10, 'count')
top10
# Out:
#           Coin  count
# 93        HYPE   7302
# 3         @107   6908
# 77         ETH   4757
# 62         BTC   3162
# 138        SOL   1720
# 130  PURR/USDC    539
# 83         FTT    437
# 159        WLD    414
# 79    FARTCOIN    412
# 20          @4    391

# %%
# check every coin by clasification
ct = pd.crosstab(bitcoin[bitcoin['Coin']=='@4']['Coin'], bitcoin['classification'], normalize='index')*100
ct
# Out:
# classification  Extreme Fear  Extreme Greed      Fear     Greed   Neutral
# Coin
# @4                  7.161125      20.204604  12.02046  48.59335  12.02046

# %% [markdown]
# # top 10 trade coins basis classification
# - hype fear 75% greed 24%
# - @107 fear 22% greed 62%
# - ETH fear 50% greed 43%
# - BTC fear 36% greed 57%
# - SOL fear 69% greed 39%
# - PURR/USDC fear 32% greed 60%
# - FTT fear 30 greed 61
# - WLD fear 31 greed 58
# - FARTCOIN fear 30 and greed 65
# - @4 fear 20 greed 68

# %%
# avgerag data of numerical vs classification
for col in bitcoin.select_dtypes(include=np.number):
    print(bitcoin.groupby('classification')[col].median().reset_index())
# Out:
#   classification  Execution Price
# 0   Extreme Fear          12.1740
# 1  Extreme Greed          15.1690
# 2           Fear          17.7460
# 3          Greed          19.5495
# 4        Neutral          13.3225
#   classification  Size Tokens
# 0   Extreme Fear         50.0
# 1  Extreme Greed         21.0
# 2           Fear         29.0
# 3          Greed         25.0
# 4        Neutral         32.0
#   classification  Size USD
# 0   Extreme Fear    599.12
# 1  Extreme Greed    365.00
# 2           Fear    703.88
# 3          Greed    675.08
# 4        Neutral    411.81
#   classification  Start Position
# 0   Extreme Fear    10598.080000
# 1  Extreme Greed     2155.348602
# 2           Fear       11.367760
# 3          Greed        6.633095
# 4        Neutral     3105.495947
#   classification  Closed PnL
# 0   Extreme Fear     0.00000
# 1  Extreme Greed     0.96048
# 2           Fear     0.00000
# 3          Greed     0.00000
# 4        Neutral     0.00000
#   classification      Order ID
# 0   Extreme Fear  8.351672e+10
# 1  Extreme Greed  5.451028e+10
# 2           Fear  6.927051e+10
# 3          Greed  6.815036e+10
# 4        Neutral  5.413330e+10
#   classification       Fee
# 0   Extreme Fear  0.102816
# 1  Extreme Greed  0.034977
# 2           Fear  0.105617
# 3          Greed  0.101071
# 4        Neutral  0.017402
#   classification      Trade ID
# 0   Extreme Fear  5.660000e+14
# 1  Extreme Greed  5.590000e+14
# 2           Fear  5.640000e+14
# 3          Greed  5.570000e+14
# 4        Neutral  5.660000e+14
#   classification     Timestamp
# 0   Extreme Fear  1.740000e+12
# 1  Extreme Greed  1.730000e+12
# 2           Fear  1.740000e+12
# 3          Greed  1.740000e+12
# 4        Neutral  1.730000e+12
#   classification   net pnl
# 0   Extreme Fear -0.051321
# 1  Extreme Greed  0.914723
# 2           Fear -0.017112
# 3          Greed -0.001517
# 4        Neutral  0.057187
#   classification  hours
# 0   Extreme Fear   13.0
# 1  Extreme Greed   14.0
# 2           Fear   11.0
# 3          Greed    9.0
# 4        Neutral   13.0
#   classification  usd per token
# 0   Extreme Fear      12.173999
# 1  Extreme Greed      15.169055
# 2           Fear      17.745919
# 3          Greed      19.548950
# 4        Neutral      13.322019
#   classification     timestamp
# 0   Extreme Fear  1.741066e+09
# 1  Extreme Greed  1.731389e+09
# 2           Fear  1.740980e+09
# 3          Greed  1.735882e+09
# 4        Neutral  1.728711e+09
#   classification  value
# 0   Extreme Fear   15.0
# 1  Extreme Greed   80.0
# 2           Fear   28.0
# 3          Greed   71.0
# 4        Neutral   49.0

# %% [markdown]
# # Conclusions
# - Extreme Greed is the best time for profit-booking.
# - Extreme Fear is the best time to buy any coin while having the 2nd highest fee.
# - Best Session for selling is night because from morning and night, greed is increasing and fear is the same.
# - Most liquid/popular coins is overall fear-driven HYPE and SOL, and overall greed-driven are @107, BTC, FTT, WLD, FARTCOIN, @4 and PURR/USD.
# - Features like fee, order ID, timestamp, and execution price can be used for model calibration or abnormal detection trend.
# - Greed is very dangerous for buying due to  higher token size, larger position, and negative Net pnl because buying at a higher price or overvaluation.

# %% [markdown]
# # Risks
# - Extreme greed selling risky due to overvaluation (suddenly convert extreme fear quickly, or coin fraud comes out).
# - Extreme fear of buying risky due to the market going further downwards.
# - Night is more greedy risky due to market uncertainty, it may change or not follow the trend this time.
# - Features give an abnormal trend risky due to market uncertainty,  may give a wrong trend or change the trend when we enter.
